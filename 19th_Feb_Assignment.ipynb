# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Ans. Flask is a web framework, it’s a Python module that lets you develop web applications easily. It’s has a small and easy-to-extend core: it’s a microframework that doesn’t include an ORM (Object Relational Manager) or such features. It does have many cool features like url routing, template engine. It is a WSGI web app framework.
#
# Advantages of Flask:
# - **Scalable**: Size is everything, and Flask's status as a microframework means that we can use it to grow a tech project such as a web app incredibly quickly.
# - **Flexible**: This is the core feature of Flask, and one of its biggest advantages because Flask is more flexible than Django.
# - **Lightweight**: Flask also supports modular programming, which is where its functionality can be split into several interchangeable modules. Each module acts as an independent building block, which can execute one part of the functionality. Together this means that the whole constituent parts of the structure are flexible, moveable, and testable on their own.
# - **Documentation**: Flask users can find a healthy number of examples and tips arranged in a structured manner

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "Hello World Ash!"

if __name__ == "__main__":
    app.run(host = "0.0.0.0")

# %% [markdown]
# ![Screenshot 2023-02-25 151322.png](attachment:f6404870-7e11-40a8-91fd-5aeb8c5321cd.png)

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# Ans. App Routing means mapping the URLs to a specific function that will handle the logic for that URL.
#
# Mapping the URL to a specific funtion helps to define multiple URL that routes to multiple differenct functions/methods with in a single code block.

# %% [markdown]
# ### Q4.  Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# - Company Name: ABC Corporation
# - Location: India
# - Contact Detail: 999-999-9999
#
# Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/welcome")
def welcome_page():
    return "<h1>Welcome to ABC Corporation</h1>"

@app.route("/")
def detail_page():
    detail = '''Company Name: ABC Corporation <br/> Location: India <br/> Contact Detail: 999-999-9999'''
    return detail

if __name__ == "__main__":
    app.run(host = "0.0.0.0")

# %% [markdown]
# ![detail.png](attachment:a0cbe367-cf7d-4d59-886f-14868e5df7b2.png)

# %% [markdown]
# ![welcome_page.png](attachment:9c5153a7-f47e-4b6f-9543-18730ab892ad.png)

# %% [markdown]
# ### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# Ans. To build a URL to a specific function, we use the url_for() function. It accepts the name of the function as its first argument and any number of keyword arguments, each corresponding to a variable part of the URL rule

# %%
# example for url_for() function
from flask import Flask
from flask import url_for

app = Flask(__name__)

@app.route("/")
def index():
    return "index"

@app.route("/homepage")
def homepage():
    return "This is the homepage for this example!"

@app.route("/user/<username>")
def profile(username):
    return "This is the profile for {}".format(username)

with app.test_request_context():
    print(url_for('index'))
    print(url_for('homepage'))
    print(url_for('homepage', next = '/'))
    print(url_for('profile', username = "Ashish kumar jha"))
# Out:
# /
# /homepage
# /homepage?next=%2F
# /user/Ashish%20kumar%20jha
