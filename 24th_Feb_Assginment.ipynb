# %% [markdown]
# ### Q1. List any five functions of the pandas library with execution.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
# 1. reindex print the record in the index order given as an argument
df.reindex([4,3,2,1,8,9,0])
# Out:
#    PassengerId  Survived  Pclass  \
# 4            5         0       3
# 3            4         1       1
# 2            3         1       3
# 1            2         1       1
# 8            9         1       3
# 9           10         1       2
# 0            1         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 4                           Allen, Mr. William Henry    male  35.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 0                            Braund, Mr. Owen Harris    male  22.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# 2. loc() return the record based on the named indexing
df.loc[0:5, ["Name", "Sex", "Survived", "Age"]]
# Out:
#                                                 Name     Sex  Survived   Age
# 0                            Braund, Mr. Owen Harris    male         0  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female         1  38.0
# 2                             Heikkinen, Miss. Laina  female         1  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female         1  35.0
# 4                           Allen, Mr. William Henry    male         0  35.0
# 5                                   Moran, Mr. James    male         0   NaN

# %%
# 3. head() return the first 5 (if given no argument) or the specified number of record
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 4. describe(): returns the satistical data ove the columns that contain decimal volue
# Note** If no column with decimal value is there in the dataframe then the statiscal data is return based on the column present

df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# 5. sort_value(): return the sorted dataframe based on the column name
# Ascending = Flase (means Descending)

df.sort_values("Age", ascending=False)[0:10][["Name", "Age"]] # [0:10] will return only the first 10 columns after from the sorted data frame
# Out:
#                                      Name   Age
# 630  Barkworth, Mr. Algernon Henry Wilson  80.0
# 851                   Svensson, Mr. Johan  74.0
# 493               Artagaveytia, Mr. Ramon  71.0
# 96              Goldschmidt, Mr. George B  71.0
# 116                  Connors, Mr. Patrick  70.5
# 672           Mitchell, Mr. Henry Michael  70.0
# 745          Crosby, Capt. Edward Gifford  70.0
# 33                  Wheadon, Mr. Edward H  66.0
# 54         Ostby, Mr. Engelhart Cornelius  65.0
# 280                      Duane, Mr. Frank  65.0

# %% [markdown]
# ### Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
import pandas as pd

data = {
    "A": ["Sudh","Krish","Ash","Alex","Pann"],
    "B": [35,33,24,56,17],
    "C": ["BLR", "BLR", "DEL", "BHO", "LKO"]
}


df1 = pd.DataFrame(data)
print(df1)
# Out:
#        A   B    C
# 0   Sudh  35  BLR
# 1  Krish  33  BLR
# 2    Ash  24  DEL
# 3   Alex  56  BHO
# 4   Pann  17  LKO

# %%
def indexlst(x):
    lst = []
    for i in range(1, len(x)*2,2):
        lst.append(i)
    result = df1.reindex(lst)
    return result

# %%
indexlst(df1)
# Out:
#        A     B    C
# 1  Krish  33.0  BLR
# 3   Alex  56.0  BHO
# 5    NaN   NaN  NaN
# 7    NaN   NaN  NaN
# 9    NaN   NaN  NaN

# %%
# We can also write the above code as this
df1.reindex([i for i in range(1, len(df1)*2,2)])
# Out:
#        A     B    C
# 1  Krish  33.0  BLR
# 3   Alex  56.0  BHO
# 5    NaN   NaN  NaN
# 7    NaN   NaN  NaN
# 9    NaN   NaN  NaN

# %% [markdown]
# ### Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The function should print the sum to the console.
#
# For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should
# calculate and print the sum of the first three values, which is 60.

# %%
import pandas as pd

data = {
    "Name": ["Sudh","Krish","Ash","Alex","Pann"],
    "Values": [10,20,30,40,50],
    "Location": ["BLR", "BLR", "DEL", "BHO", "LKO"]
}


df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Values Location
# 0   Sudh      10      BLR
# 1  Krish      20      BLR
# 2    Ash      30      DEL
# 3   Alex      40      BHO
# 4   Pann      50      LKO

# %%
print(df["Values"].head(3))
print("Sum is:",sum(df["Values"].head(3)))
# Out:
# 0    10
# 1    20
# 2    30
# Name: Values, dtype: int64
# Sum is: 60

# %% [markdown]
# ### Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
import pandas as pd

data = {
    "Text": ["Sudh","Krish","Ash","Alex","Pann"],
    "Values": [10,20,30,40,50],
    "Location": ["BLR", "BLR", "DEL", "BHO", "LKO"]
}


df = pd.DataFrame(data)
print(df)
# Out:
#     Text  Values Location
# 0   Sudh      10      BLR
# 1  Krish      20      BLR
# 2    Ash      30      DEL
# 3   Alex      40      BHO
# 4   Pann      50      LKO

# %%
df["Word_count"] = df["Text"].apply(lambda n: len(n))

# %%
df
# Out:
#     Text  Values Location  Word_count
# 0   Sudh      10      BLR           4
# 1  Krish      20      BLR           5
# 2    Ash      30      DEL           3
# 3   Alex      40      BHO           4
# 4   Pann      50      LKO           4

# %% [markdown]
# ### Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# Ans.
# - **dataframe.size**: Returns size of dataframe/series which is equivalent to total number of elements. That is rows x columns.
# - **dataframe.shape**: Returns tuple of shape (Rows, columns) of dataframe/series

# %%
# example (taking dataframe from the Q4)
print("Dataframe Size:",df.size)
print("Dataframe Shape:",df.shape)
# Out:
# Dataframe Size: 20
# Dataframe Shape: (5, 4)

# %% [markdown]
# ### Q6. Which function of pandas do we use to read an excel file?

# %%
# function to read excel file
import pandas as pd

# read_excel to read excel file using pandas
dataframe = pd.read_excel("ipl_dataset.xlsx")

dataframe.head() # for first five records
# Out:
#                                       full_scorecard  \
# 0  https://stats.espncricinfo.com/ci/engine/match...
# 1  https://stats.espncricinfo.com/ci/engine/match...
# 2  https://stats.espncricinfo.com/ci/engine/match...
# 3  https://stats.espncricinfo.com/ci/engine/match...
# 4  https://stats.espncricinfo.com/ci/engine/match...
#
#                          team1                  team2  team1_score  \
# 0          Chennai Super Kings  Kolkata Knight Riders        131.0
# 1               Mumbai Indians         Delhi Capitals        177.0
# 2  Royal Challengers Bangalore           Punjab Kings        205.0
# 3         Lucknow Super Giants         Gujarat Titans        158.0
# 4             Rajasthan Royals    Sunrisers Hyderabad        210.0
#
#    team2_score            toss_winner toss_choice    winner     margin  \
# 0        133.0  Kolkata Knight Riders       Field       KKR  6 wickets
# 1        179.0         Delhi Capitals       Field  Capitals  4 wickets
# ...

# %% [markdown]
# ### Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email addresses in the format 'username@domain.com'. Write a Python function that creates a new column 'Username' in df that contains only the username part of each email address.
#
# The username is the part of the email address that appears before the '@' symbol. For example, if the
# email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your
# function should extract the username from each email address and store it in the new 'Username'
# column.

# %%
import pandas as pd

data = {
    "Name": ["Sudh","Krish","Ash","Alex","Pann"],
    "Age": [10,20,30,40,50],
    "Location": ["BLR", "BLR", "DEL", "BHO", "LKO"],
    "Email": ["Sudh.kumar@pwskills.com", "krish.naik@pwskills.com", "ash.kumar@pwskills.com", "alex.brown@yahoo.com", "pann.blake@hotmail.com"]
}


df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age Location                    Email
# 0   Sudh   10      BLR  Sudh.kumar@pwskills.com
# 1  Krish   20      BLR  krish.naik@pwskills.com
# 2    Ash   30      DEL   ash.kumar@pwskills.com
# 3   Alex   40      BHO     alex.brown@yahoo.com
# 4   Pann   50      LKO   pann.blake@hotmail.com

# %%
df["Username"] = df["Email"].apply(lambda x: x.split("@")).apply(lambda i: i[0] ) # To filter out the username from the emailids
df # to print out the dataframe on console
# Out:
#     Name  Age Location                    Email    Username
# 0   Sudh   10      BLR  Sudh.kumar@pwskills.com  Sudh.kumar
# 1  Krish   20      BLR  krish.naik@pwskills.com  krish.naik
# 2    Ash   30      DEL   ash.kumar@pwskills.com   ash.kumar
# 3   Alex   40      BHO     alex.brown@yahoo.com  alex.brown
# 4   Pann   50      LKO   pann.blake@hotmail.com  pann.blake

# %% [markdown]
# ### Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The function should return a new DataFrame that contains only the selected rows.
#
# For example, if df contains the following values:
#
#   A   B   C
#
# 0  3   5   1
#
# 1  8   2   7
#
# 2  6   9   4
#
# 3  2   3   5
#
# 4  9   1   2
#
# Your function should select the following rows:
#
# A   B   C
#
# 1  8   2   7
#
# 4  9   1   2
#
# The function should return a new DataFrame that contains only the selected rows.

# %%
import pandas as pd

data = {
    "A": [3,8,6,2,6],
    "B": [5,2,9,3,1],
    "C": [1,7,4,5,2]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  6  1  2

# %%
df[(df["A"] > 5) & (df["B"] < 10)]
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  6  1  2

# %% [markdown]
# ### Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean, median, and standard deviation of the values in the 'Values' column.

# %%
import pandas as pd

data = {
    "Text": ["Sudh","Krish","Ash","Alex","Pann"],
    "Values": [35,35,24,55,32],
    "Location": ["BLR", "BLR", "DEL", "BHO", "LKO"]
}


df = pd.DataFrame(data)
print(df)
# Out:
#     Text  Values Location
# 0   Sudh      35      BLR
# 1  Krish      35      BLR
# 2    Ash      24      DEL
# 3   Alex      55      BHO
# 4   Pann      32      LKO

# %%
def values_desc(df):

    return f'''Mean is: {df["Values"].mean()}, Median is: {df["Values"].median()}, Standard Deviation is: {df["Values"].std()}'''

values_desc(df)
# Out:
# 'Mean is: 36.2, Median is: 35.0, Standard Deviation is: 11.43241006962224'

# %% [markdown]
# ### Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days for each row in the DataFrame. The moving average should be calculated using a window of size 7 and should include the current day.

# %%
import pandas as pd
from functools import reduce

df = pd.read_csv("Salesstore.csv")

# %%
print(df["Sales"][0:8])
print(sum(df["Sales"][0:8]))
# Out:
# 0    2781.82
# 1    3389.93
# 2    2039.56
# 3     905.94
# 4    1168.15
# 5     237.28
# 6    1368.14
# 7    4429.69
# Name: Sales, dtype: float64
# 16320.509999999998

# %%
# [list(df["Sales"][i:i+7]) for i in df.index]
df["MovingAverage"] = pd.Series([round(sum(i),2) for i in [list(df["Sales"][i-6:i+1]) for i in df.index]])

# %%
df[["Date", "Sales", "MovingAverage"]].head(14)
# Out:
#           Date     Sales  MovingAverage
# 0   2021-01-01   2781.82           0.00
# 1   2021-01-02   3389.93           0.00
# 2   2021-01-03   2039.56           0.00
# 3   2021-01-04    905.94           0.00
# 4   2021-01-05   1168.15           0.00
# 5   2021-01-06    237.28           0.00
# 6   2021-01-07   1368.14       11890.82
# 7   2021-01-08   4429.69       13538.69
# 8   2021-01-09  19109.61       29258.37
# 9   2021-01-10   2475.08       29693.89
# 10  2021-01-11    446.53       29234.48
# 11  2021-01-12   2780.88       30847.21
# 12  2021-01-13    198.72       30808.65
# 13  2021-01-14   4012.58       33453.09

# %% [markdown]
# ### Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g. Monday, Tuesday) corresponding to each date in the 'Date' column.
#
# For example, if df contains the following values:
#
#          Date
#
# 0  2023-01-01
#
# 1  2023-01-02
#
# 2  2023-01-03
#
# 3  2023-01-04
#
# 4  2023-01-05
#
# Your function should create the following DataFrame:
#
#          Date    Weekday
#
# 0  2023-01-01    Sunday
#
# 1  2023-01-02     Monday
#
# 2  2023-01-03    Tuesday
#
# 3  2023-01-04    Wednesday
#
# 4  2023-01-05    Thursday
#
# The function should return the modified DataFrame

# %%
import pandas as pd

data = {"Date": ["2023-01-01", "2023-01-02", "2023-01-03", "2023-01-04", "2023-01-05"]}
df = pd.DataFrame(data)
# df = df["Date"].apply(pd.to_datetime)
df
# Out:
#          Date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05

# %%
sr = pd.date_range(df["Date"][0], df["Date"][len(df)-1], freq="D").to_series()

# %%
def weekday_df(x):
    if x == 0:
        return "Monday"
    if x == 1:
        return "Tuesday"
    if x == 2:
        return "Wednesday"
    if x == 3:
        return "Thursday"
    if x == 4:
        return "Friday"
    if x == 5:
        return "Saturday"
    if x == 6:
        return "Sunday"

# df["Weekday"] = 

df["Weekday"] = list(sr.dt.dayofweek.apply(lambda x: weekday_df(x)))
df
# Out:
#          Date    Weekday
# 0  2023-01-01     Sunday
# 1  2023-01-02     Monday
# 2  2023-01-03    Tuesday
# 3  2023-01-04  Wednesday
# 4  2023-01-05   Thursday

# %% [markdown]
# ### Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
import pandas as pd

df = pd.read_excel("Salesstore_Q12.xlsx")
df.columns
# Out:
# Index(['Order_ID', 'Order_Priority', 'Order_Quantity', 'Date', 'Sales',
#        'Ship_Mode', 'Profit', 'Customer_Name', 'Region', 'Customer_Segment',
#        'Product_Category', 'Product_Sub-Category', 'Product_Name',
#        'Product_Container'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Order_ID                         int64
# Order_Priority                  object
# Order_Quantity                   int64
# Date                    datetime64[ns]
# Sales                          float64
# Ship_Mode                       object
# Profit                         float64
# Customer_Name                   object
# Region                          object
# Customer_Segment                object
# Product_Category                object
# Product_Sub-Category            object
# Product_Name                    object
# Product_Container               object
# dtype: object

# %%
# df[(df["Date"] >= "2023-01-01") & (df["Date"] <= "2023-01-31")]
# pd.date_range(df["Date"][0], df["Date"][len(df)-1], freq="D").to_series()
# df["Date"].apply(pd.Timestamp)

df[(df["Date"].apply(lambda x: str(x.date())) >= "2023-01-01") & (df["Date"].apply(lambda x: str(x.date())) <= "2023-01-31")]
# Out:
#      Order_ID Order_Priority  Order_Quantity                    Date  \
# 295     49634  Not Specified              45 2023-01-01 13:51:59.995
# 296     53825            Low              36 2023-01-02 13:51:59.995
# 297     21509           High              13 2023-01-03 13:51:59.995
# 298     52326            Low              41 2023-01-04 13:51:59.995
# 299     54947  Not Specified              42 2023-01-05 13:51:59.995
# 300      4257         Medium              45 2023-01-06 13:51:59.995
# 301      5698         Medium              15 2023-01-07 13:51:59.995
# 302      5698         Medium               7 2023-01-08 13:51:59.995
# 303     11301         Medium              29 2023-01-09 13:51:59.995
# 304     16161         Medium              49 2023-01-10 13:51:59.995
# 305     20038            Low              42 2023-01-11 13:51:59.995
# 306     20422           High               5 2023-01-12 13:51:59.995
# 307     24450       Critical              37 2023-01-13 13:51:59.995
# ...

# %% [markdown]
# ### Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to be imported?

# %% [markdown]
# Ans. We need to import pandas before using any function that is associated with the pandas.
